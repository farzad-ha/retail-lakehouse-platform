# %%
# %sql
-- a sample to validate the bronze table contains expected data and metadate columns
SELECT *
FROM first_data_engineering_project.bronze.bronze_orders
LIMIT 10;

# %%
# %sql
-- validate that the correct number of rows have been ingested
SELECT COUNT(*) as total_rows
FROM first_data_engineering_project.bronze.bronze_orders;

# %%
# %sql

-- inspect the bronze table metadata
DESCRIBE DETAIL first_data_engineering_project.bronze.bronze_orders;
